# %%
import requests
import re
 
response = requests.get("https://www.sslproxies.org/")
proxy_ips = re.findall('\d+\.\d+\.\d+\.\d+:\d+', response.text)  #「\d+」代表數字一個位數以上
valid_ips = []
for ip in proxy_ips:
    try:
        result = requests.get('https://ip.seeip.org/jsonip?',
			       proxies={'http': ip, 'https': ip},
			       timeout=5)
        print(result.json())
        valid_ips.append(ip)
    except:
        print(f"{ip} invalid")
# Out:
# 47.242.254.88:8888 invalid
# {'ip': '2a06:a003:5051::2'}
# 198.59.191.234:8080 invalid
# 8.219.97.248:80 invalid
# 130.41.15.76:8080 invalid
# {'ip': '81.12.44.199'}
# 130.41.55.190:8080 invalid
# {'ip': '150.230.53.13'}
# 200.105.215.18:33630 invalid
# 45.79.208.64:44554 invalid
# 20.81.62.32:3128 invalid
# 47.91.107.251:3080 invalid
# 194.195.216.153:4145 invalid
# 173.255.209.155:1080 invalid
# 8.214.4.72:33080 invalid
# {'ip': '2a01:238:423f:a200:32e8:8395:5030:a0f8'}
# 139.162.44.152:22365 invalid
# 133.18.227.47:8080 invalid
# 94.74.117.93:2526 invalid
# 178.128.211.134:6868 invalid
# {'ip': '113.108.148.102'}
# 133.18.175.198:8080 invalid
# 167.99.194.95:8048 invalid
# {'ip': '133.18.197.218'}
# 96.126.103.64:999 invalid
# 133.18.173.81:8080 invalid
# 222.237.249.172:8080 invalid
# 43.225.140.143:30001 invalid
# 85.195.104.71:80 invalid
# 8.209.127.181:1080 invalid
# 68.183.185.62:80 invalid
# 41.65.174.120:1976 invalid
# 197.243.14.45:8889 invalid
# 192.99.182.243:3128 invalid
# 47.88.8.118:30001 invalid
# 172.105.25.190:8020 invalid
# 182.253.141.63:8080 invalid
# 45.56.83.46:8013 invalid
# 47.242.12.6:9000 invalid
# 8.211.22.130:5678 invalid
# 27.159.66.41:20183 invalid
# 47.101.145.157:9128 invalid
# 110.34.1.46:3128 invalid
# 117.121.204.9:7998 invalid
# 85.159.214.61:4145 invalid
# 119.3.122.177:5566 invalid
# 172.105.107.25:999 invalid
# 45.56.75.90:5344 invalid
# 172.105.190.51:8017 invalid
# 133.18.194.45:8080 invalid
# 5.196.63.97:8080 invalid
# 167.235.66.172:30001 invalid
# 45.79.253.142:4153 invalid
# 47.250.47.37:1100 invalid
# 45.79.111.38:9991 invalid
# 158.101.158.79:1080 invalid
# 178.63.62.94:10001 invalid
# 164.138.103.163:3128 invalid
# 133.18.203.28:8080 invalid
# 172.104.241.29:808 invalid
# 186.215.87.194:6062 invalid
# 213.14.174.70:3128 invalid
# 95.217.208.163:8118 invalid
# 178.79.191.47:54417 invalid
# 182.253.108.50:40448 invalid
# {'ip': '45.167.125.97'}
# 5.44.62.166:8080 invalid
# 170.245.164.34:999 invalid
# 181.78.94.22:9991 invalid
# 95.217.62.36:3128 invalid
# 193.164.16.184:2019 invalid
# 139.59.228.95:8118 invalid
# 196.219.202.74:8080 invalid
# 23.229.21.168:3128 invalid
# 152.231.29.51:8080 invalid
# 47.89.185.178:8888 invalid
# 171.5.13.238:34599 invalid
# {'ip': '157.100.12.138'}
# 170.83.77.21:999 invalid
# 104.225.216.223:3128 invalid
# 103.1.93.184:55443 invalid
# 85.14.243.31:3128 invalid
# 181.198.40.145:999 invalid
# 163.172.215.211:3128 invalid
# 170.83.242.250:999 invalid
# 175.138.229.109:3128 invalid
# 187.190.0.240:999 invalid
# 62.193.108.135:1981 invalid
# 62.193.108.131:1981 invalid
# 66.94.121.32:3128 invalid
# 185.17.132.15:2536 invalid
# 154.236.168.169:1976 invalid
# {'ip': '122.155.165.191'}
# 104.225.216.161:3128 invalid
# 187.188.232.250:999 invalid
# 62.193.68.91:1976 invalid
# {'ip': '181.225.68.29'}
# 94.230.183.226:8080 invalid
# 96.126.124.197:81 invalid
# 110.238.104.109:30001 invalid

# %%
with open('proxy_list.txt', 'w') as file:
    for ip in valid_ips:
        file.write(ip + '\n')
    file.close()
